# %%
import PIL
import numpy as np
import matplotlib.pyplot as plt

import IPython.display 

import os

# %%
img=PIL.Image.open('J_1.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x19BC9CC0850>

# %%
#im1 = Image.open(IMAGE_FILE)

import os
IMAGE_0 = os.path.join(r'C:\Users\lutfu\GIT_Notebook\J_1_0.jpg') 
img.save(IMAGE_0,"JPEG", quality=0)
im0 = PIL.Image.open(IMAGE_0)
im0
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x19BCBF25E80>

# %%
IMAGE_50 = os.path.join(r'C:\Users\lutfu\GIT_Notebook\J_1_50.jpg')
img.save(IMAGE_50,"JPEG", quality=50)
im50 = PIL.Image.open(IMAGE_50)
im50
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x19BCBF25D00>

# %%
IMAGE_100 = os.path.join(r'C:\Users\lutfu\GIT_Notebook\J_1_100.jpg')
img.save(IMAGE_100,"JPEG", quality=100)
im100 = PIL.Image.open(IMAGE_100)
im100
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x19BCBF3CD60>

# %%
a = IPython.display.Image(filename='J_1.jpg') 
b = IPython.display.Image(filename='J_1_0.jpg') 
c = IPython.display.Image(filename='J_1_50.jpg') 
d = IPython.display.Image(filename='J_1_100.jpg') 
IPython.display.display(a,b,c,d)

# %%
img=PIL.Image.open('J_1.jpg')

def M_function(img):
    IMAGE_0 = os.path.join(r'C:\Users\lutfu\GIT_Notebook\J_1_0.jpg') 
    img.save(IMAGE_0,"JPEG", quality=10)
    im0 = PIL.Image.open(IMAGE_0)
    
    
    IMAGE_50 = os.path.join(r'C:\Users\lutfu\GIT_Notebook\J_1_50.jpg')
    img.save(IMAGE_50,"JPEG", quality=50)
    im50 = PIL.Image.open(IMAGE_50)
    
    IMAGE_100 = os.path.join(r'C:\Users\lutfu\GIT_Notebook\J_1_100.jpg')
    img.save(IMAGE_100,"JPEG", quality=100)
    im100 = PIL.Image.open(IMAGE_100)
    
    a = IPython.display.Image(filename='J_1.jpg') 
    b = IPython.display.Image(filename='J_1_0.jpg') 
    c = IPython.display.Image(filename='J_1_50.jpg') 
    d = IPython.display.Image(filename='J_1_100.jpg') 
    IPython.display.display(a,b,c,d)
   
M_function(img)
